# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('AB_NYC_2019.csv')

# %%
df.head(6)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
# ...

# %%
df.price.describe()

# describing only on price
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df.price.quantile(0)
# Out:
# 0.0

# %%
df.price.quantile(0.25)
# Out:
# 69.0

# %%
df.price.quantile(0.50)
# Out:
# 106.0

# %%
df.price.quantile(0.75)
# Out:
# 175.0

# %%
df.price.quantile(0.25, interpolation='higher')

# interpolation = higheer gives high value of two values
# Out:
# 69

# %%
df.price.quantile(0.75, interpolation='lower')
# Out:
# 175

# %%
df.price.quantile(1) # max
# Out:
# 10000.0

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
# max is outlier now

# %%
df.price.quantile(0.98)
# Out:
# 550.0

# %%
df.price.quantile(0.99)
# Out:
# 799.0

# %%
percentile_98 = df.price.quantile(0.98)

# %%
percentile_98
# Out:
# 550.0

# %%
df[df.price > percentile_98]
# Out:
#              id                                               name    host_id  \
# 85        19601                perfect for a family or small group      74303
# 299       68974                 Unique spacious loft on the Bowery     281229
# 345       89427                               The Brooklyn Waverly     116599
# 365      103311                  2 BR w/ Terrace @ Box House Hotel     417504
# 496      174966              Luxury 2Bed/2.5Bath Central Park View     836168
# ...         ...                                                ...        ...
# 48523  36308562  Tasteful & Trendy Brooklyn Brownstone, near Train  217732163
# 48535  36311055     Stunning & Stylish Brooklyn Luxury, near Train  245712163
# 48697  36388720         HUGE LUXURY CONDO – INCREDIBLE WATER VIEWS  273619215
# 48757  36419574     Luxury & Spacious 1500 ft² MANHATTAN Townhouse   11454384
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
#
# ...

# %%
df.price
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
min_threshold, max_threshold = df.price.quantile([0.01, 0.999])

# %%
min_threshold, max_threshold
# Out:
# (30.0, 3000.0)

# %%
# min is 30.0

# %%
# max is 3000.0
# Out:
# 135

# %%
df[df.price < min_threshold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df2 = df[(df.price > min_threshold) & (df.price < max_threshold)]

# %%
df2
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df2.sample(7)
# Out:
#              id                                               name    host_id  \
# 9636    7400486                      My Spacious & Comfy Home Away   32604265
# 10598   8151536                Sunny Room in Williamsburg Brooklyn   24982391
# 11330   8801963           Sunny Room With Charming Slate Fireplace   23582893
# 6292    4598265                Hamilton Hts Beauty, Manhattan 1 BR   23834677
# 15572  12539359                          Cute and cosy one bedroom   60946174
# 23400  18942156  Extreme Luxury Apt @ Times Sq w amazing river ...    2340947
# 27178  21485174                Large One Bedroom in NYC Brownstone  156060717
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9636   Shaquana            Brooklyn    Crown Heights  40.67647  -73.94813
# 10598   Maythem            Brooklyn     Williamsburg  40.71248  -73.96379
# 11330   Laramie            Brooklyn         Bushwick  40.69036  -73.91608
# ...

# %%
df2.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.818300e+04  4.818300e+04  48183.000000  48183.000000  48183.000000
# mean   1.896272e+07  6.723035e+07     40.729155    -73.952498    148.772036
# std    1.099404e+07  7.851540e+07      0.054231      0.045894    153.594795
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     31.000000
# 25%    9.411247e+06  7.719674e+06     40.690355    -73.983190     70.000000
# 50%    1.960306e+07  3.038419e+07     40.723280    -73.955930    110.000000
# 75%    2.910493e+07  1.072455e+08     40.763180    -73.936960    179.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990   2999.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48183.000000       48183.000000       38312.000000
# mean         7.011104          23.393915           1.373749
# std         20.526646          44.701116           1.680887
# ...

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64

# %%
df2
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df['price'][4] = np.NaN 

# simply giving after 4 price values means 5th value as NaN
# to get mean median ...
# Out:
# C:\Users\MONISHA JAIN\AppData\Local\Temp\ipykernel_16848\256578100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][4] = np.NaN

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.price.mean()
# Out:
# 152.72217449993863

# %%
df_fill_na_Mean = df.fillna(df.price.mean())

# %%
df_fill_na_Mean
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.price.median()
# Out:
# 106.0

# %%
df_fill_na_Median = df.fillna(df.price.median())

# %%
df_fill_na_Median
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...
